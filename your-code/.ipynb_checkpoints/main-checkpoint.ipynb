# %% [markdown]
# # Challenge: Rick and Morty API
#
# ![](http://as01.epimg.net/epik/imagenes/2019/02/12/portada/1549970850_227267_1549973816_noticia_normal.jpg)
#
#
# **In this challenge, you'll develop codes to parse and analyze data returned from the [Rick and Morty API](https://rickandmortyapi.com/).** The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
#import requests
#data=requests.get('https://rickandmortyapi.com/api/character')

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import requests
import pandas as pd
from pandas.io.json import json_normalize

data=requests.get('https://rickandmortyapi.com/api/character')
data
# Out:
# <Response [200]>

# %%
results = data.json()
results

flattened_data = json_normalize(results['results'])
flattened_data
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16000\3085970597.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data = json_normalize(results['results'])
#     id                       name   status species  \
# 0    1               Rick Sanchez    Alive   Human
# 1    2                Morty Smith    Alive   Human
# 2    3               Summer Smith    Alive   Human
# 3    4                 Beth Smith    Alive   Human
# 4    5                Jerry Smith    Alive   Human
# 5    6  Abadango Cluster Princess    Alive   Alien
# 6    7           Abradolf Lincler  unknown   Human
# 7    8           Adjudicator Rick     Dead   Human
# 8    9            Agency Director     Dead   Human
# 9   10                 Alan Rails     Dead   Human
# 10  11            Albert Einstein     Dead   Human
# 11  12                  Alexander     Dead   Human
# 12  13               Alien Googah  unknown   Alien
# ...

# %%
total_pages=results['info']['pages']
total_pages
# Out:
# 42

# %%
df=pd.DataFrame()

for page in range(2,43):
    k = page
    url = f'https://rickandmortyapi.com/api/character/?page={k}'
    response = requests.get(url)
    response = response.json()
    flattered_response = json_normalize(response['results'])
    flattened_data = pd.concat([flattened_data,flattered_response],axis=0) #une todas las páginas
df = flattened_data
df.head(6)
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16000\1238317245.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattered_response = json_normalize(response['results'])
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16000\1238317245.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattered_response = json_normalize(response['results'])
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16000\1238317245.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattered_response = json_normalize(response['results'])
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_16000\1238317245.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattered_response = json_normalize(response['results'])
# ...

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The character who appeared in most episodes (aside from Rick and Morty, of course!).
#
# * The total number of dead characters.
#
# * A list of all character origins (without duplicates).

# %%
# your code here

#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html
df.sort_values(by='episode_counter',ascending = True)

character_in_most_episodes = df[(df['name'] != 'Rick Sanchez')&(df['name'] != 'Morty Smith')]
character_in_most_episodes.head(5)
# Out:
#    id                       name   status species                type  gender  \
# 2   3               Summer Smith    Alive   Human                      Female
# 3   4                 Beth Smith    Alive   Human                      Female
# 4   5                Jerry Smith    Alive   Human                        Male
# 5   6  Abadango Cluster Princess    Alive   Alien                      Female
# 6   7           Abradolf Lincler  unknown   Human  Genetic experiment    Male
#
#                                                image  \
# 2  https://rickandmortyapi.com/api/character/avat...
# 3  https://rickandmortyapi.com/api/character/avat...
# 4  https://rickandmortyapi.com/api/character/avat...
# 5  https://rickandmortyapi.com/api/character/avat...
# 6  https://rickandmortyapi.com/api/character/avat...
#
#                                              episode  \
# 2  [https://rickandmortyapi.com/api/episode/6, ht...
# 3  [https://rickandmortyapi.com/api/episode/6, ht...
# ...

# %%
df['status'].value_counts()
# Out:
# Alive      1301
# Dead        849
# unknown     288
# Name: status, dtype: int64

# %%
#character_origins=list(df['location.name'])
character_origins=list(df['origin.name'])  
character_origins=set(character_origins)#For  Python sets, duplicated items are not allowed
character_origins=list(character_origins)
character_origins.sort()
character_origins
#len(character_origins)
# Out:
# ['Abadango',
#  'Alphabetrium',
#  'Anatomy Park',
#  'Avian Planet',
#  'Bepis 9',
#  'Bird World',
#  "Birdperson's Consciousness",
#  'Citadel of Ricks',
#  'Cronenberg Earth',
#  'Detoxifier',
#  'Draygon',
#  'Earth (5-126)',
#  'Earth (C-137)',
#  'Earth (C-500A)',
#  'Earth (Chair Dimension)',
#  'Earth (D-99)',
#  'Earth (D716)',
#  'Earth (D716-B)',
#  'Earth (D716-C)',
#  "Earth (Evil Rick's Target Dimension)",
#  'Earth (Fascist Dimension)',
#  'Earth (Fascist Shrimp Dimension)',
#  'Earth (Fascist Teddy Bear Dimension)',
#  'Earth (Giant Telepathic Spiders Dimension)',
#  'Earth (J-22)',
#  'Earth (J19ζ7)',
#  'Earth (K-22)',
#  'Earth (K-83)',
#  'Earth (Phone Dimension)',
#  'Earth (Pizza Dimension)',
#  'Earth (Replacement Dimension)',
#  'Earth (Tusk Dimension)',
#  'Earth (Unknown dimension)',
#  'Earth (Wasp Dimension)',
#  'Elemental Rings',
#  'Eric Stoltz Mask Earth',
#  'Fantasy World',
#  'Ferkus 9',
#  'France',
#  'Gaia',
#  'Gazorpazorp',
#  'Gear World',
# ...
